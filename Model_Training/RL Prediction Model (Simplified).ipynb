# %% [markdown]
# # 🌟 **Oguz Arslan MS Thesis**

# %% [markdown]
# # ⚽ **Rocket League Prediction Model** 🚗

# %% [markdown]
# ## 🎨 **Table of Contents**
# 1. [Introduction](#introduction)
# 2. [Data Analysis](#data-analysis)
# 3. [Results](#results)
# 4. [Conclusion](#conclusion)

# %% [markdown]
# ### <a id="introduction"></a> 🔍 **Introduction**
# Welcome to this notebook! Here we take the popular video game [Rocket League](https://en.wikipedia.org/wiki/Rocket_League) (RL) and train a goal scoring prediction model using past professional esports matches.

# %% [markdown]
# <div align="center">
#     <img src="Images/Example Gameplay.gif" alt="GIF example gameplay" width="700"/>
# </div>

# %% [markdown]
# #### 💬 **Dataset Description**
# The dataset consists of sequences of snapshots of the state of a RL match, including position and velocity of all players and the ball, as well as extra information. The **goal** is to predict -- from a given snapshot in the game -- for each team, the probability that they will score within the next 10 seconds of game time.
#
# The data was taken from professional RL matches. Each event consists of a chronological series of frames recorded at 10 frames per second. All events begin with a kickoff, and most end in one team scoring a goal, but some are truncated and end with no goal scored due to circumstances which can cause gameplay strategies to shift, for example 1) nearing end of regulation (where the game continues until the ball touches the ground) or 2) becoming non-competitive, e.g. one team winning by 3+ goals with little time remaining.

# %% [markdown]
# #### 🗃️ **Dataset Columns**
# - **`game_num`** _(train only)_: Unique identifier for the game from which the event was taken.
# - **`event_id`** _(train only)_: Unique identifier for the sequence of consecutive frames.
# - **`event_time`** _(train only)_: Time in seconds before the event ended, either by a goal being scored or simply when we decided to truncate the timeseries if a goal was not scored.
# - **`ball_pos_[xyz]`**: Ball's position as a 3D vector.
# - **`ball_vel_[xyz]`**: Ball's velocity as a 3D vector.
# - For `i` in `[0,6)`:
#     - **`p{i}_pos_[xyz]`**: Player `i`'s position as a 3D vector.
#     - **`p{i}_vel_[xyz]`**: Player `i`'s velocity as a 3D vector.
#     - **`p{i}_boost`**: Player `i`'s boost remaining, in `[0, 100]`. A player can consume boost to substantially increase their speed, and is required to fly up into the `z` dimension (besides driving up a wall, or the small air gained by a jump).
#     - All `p{i}` columns will be `NaN` if and only if the player is [demolished](https://rocketleague.fandom.com/wiki/Demolition) (destroyed by an enemy player; will respawn after 3 seconds).
#     - Players 0, 1, and 2 make up team `A` and players 3, 4, and 5 make up team `B`.
#     - The orientation vector of the player's car (which way the car is facing) does not necessarily match the player's velocity vector, and this dataset does not capture orientation data.
# - For `i` in `[0, 6)`:
#     - **`boost{i}_timer`**: Time in seconds until big boost orb `i` respawns, or `0` if it is available. Big boost orbs grant a full 100 boost to a player driving over it. The orb `(x, y)` locations are roughly `[ (-61.4, -81.9), (61.4, -81.9), (-71.7, 0), (71.7, 0), (-61.4, 81.9), (61.4, 81.9) ]` with `z = 0`. (Players can also gain boost from small boost pads across the map, but we do not capture those pads in this dataset.)
# - **`player_scoring_next`** _(train only)_: Which player scores at the end of the current event, in `[0, 6)`, or `-1` if the event does not end in a goal.
# - **`team_scoring_next`** _(train only)_: Which team scores at the end of the current event (`A` or `B`), or `NaN` if the event does not end in a goal.
# - **`team_[A|B]_scoring_within_10sec`** _(train only)_: **[Target columns]** Value of `1` if `team_scoring_next == [A|B]` and `time_before_event` is in `[-10, 0]`, otherwise `0`.
# - **`id`** _(test only)_: Unique identifier for each test row. The result should be a pair of `team_A_scoring_within_10sec` and `team_B_scoring_within_10sec` probability predictions for each `id`, where the predictions can range the real numbers from `[0, 1]`.

# %% [markdown]
# #### 🔢 **Useful Game Values**
# For more information, check out [RLBot Wiki](https://wiki.rlbot.org/botmaking/useful-game-values/).
#
# <img src="Images/Map Dimensions.png" alt="image" width="500"/> <img src="Images/Boost Pad Locations.png" alt="image" width="466"/>

# %% [markdown]
# #### <a id="data-analysis"></a> 📊 **Data Analysis**
# In this section, we will dive deep into the data using various tools and techniques.

# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv(r'C:\Users\Arslan\Desktop\All Data\train_0.csv') # The data frame

# %% [markdown]
# #### ✏️ **Tutorial Block**

# %%
# Read headers
df.columns

# Read a selected column (from rows 0 to 4)
df['game_num'][0:5] 

# Read many selected columns (from rows 0 to 9)
df[['game_num', 'p1_pos_y', 'p1_boost']][0:10]

# Read a selected row
df.iloc[0]

# Read many selected rows
df.iloc[[1, 3, 5]] # or df.iloc[1:7]

# Read a specific location (15th row and 23rd column)
df.iloc[15,23]

# Length of the rows
len(df)
# Out:
# 2149381

# %%
# Iterating through rows 
for index, row in df.head(10).iterrows(): ## Loop through the first 10 rows
    print(index, row['game_num']) ## Print the index and game number for each row

# %% [markdown]
# #### 🧩 **Simplified GNN Model**

# %%
# Getting the first 5 games from the dataset
first_five_games = []
index = 0

while index < len(df) and df.loc[index, 'game_num'] <= 5:
    first_five_games.append(df.loc[index])
    index += 1

# Output the length of previously visited rows
print("Number of samples:", len(first_five_games))

# Selecting only the desired columns
columns_to_select = ['', '']
# Out:
# Number of samples: 12794
# [game_num                              1
#  event_id                           1002
#  event_time                    -33.31303
#  ball_pos_x                         -0.0
#  ball_pos_y                          0.0
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 0, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -33.206146
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 1, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -33.098114
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 2, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -32.99319
#  ball_pos_x                         -0.0
#  ball_pos_y                          0.0
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 3, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -32.887756
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 4, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -32.781353
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 5, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -32.671074
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 6, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -32.56163
#  ball_pos_x                         -0.0
#  ball_pos_y                          0.0
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 7, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -32.454773
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 8, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -32.34244
#  ball_pos_x                         -0.0
#  ball_pos_y                          0.0
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 9, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -32.24011
#  ball_pos_x                         -0.0
#  ball_pos_y                          0.0
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 10, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -32.130085
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 11, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -32.022385
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 12, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -31.91648
#  ball_pos_x                         -0.0
#  ball_pos_y                          0.0
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 13, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.806765
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 14, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.689737
#  ball_pos_x                          -0.0
#  ball_pos_y                           0.0
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 15, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.578197
#  ball_pos_x                        -3.388
#  ball_pos_y                        1.2684
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 16, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.469347
#  ball_pos_x                       -9.8492
#  ball_pos_y                        1.5484
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 17, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.363832
#  ball_pos_x                    -14.909599
#  ball_pos_y                        1.7684
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 18, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.253523
#  ball_pos_x                       -20.414
#  ball_pos_y                        2.0068
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 19, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.138983
#  ball_pos_x                      -28.1832
#  ball_pos_y                        2.3434
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 20, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -31.030445
#  ball_pos_x                       -33.647
#  ball_pos_y                         2.581
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 21, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.924688
#  ball_pos_x                      -39.5472
#  ball_pos_y                        2.8364
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 22, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.809055
#  ball_pos_x                      -44.5244
#  ball_pos_y                         3.052
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 23, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.693726
#  ball_pos_x                      -50.8388
#  ball_pos_y                        3.3264
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 24, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.583298
#  ball_pos_x                      -57.5794
#  ball_pos_y                        3.6184
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 25, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.471138
#  ball_pos_x                    -63.847202
#  ball_pos_y                          3.89
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 26, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -30.36156
#  ball_pos_x                     -69.6472
#  ball_pos_y                       4.1422
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 27, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.248276
#  ball_pos_x                      -74.9842
#  ball_pos_y                        4.3732
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 28, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.143518
#  ball_pos_x                      -79.3404
#  ball_pos_y                         4.597
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 29, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -30.035393
#  ball_pos_x                      -76.1602
#  ball_pos_y                        4.5706
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 30, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -29.927746
#  ball_pos_x                      -72.7264
#  ball_pos_y                         4.542
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 31, Length: 61, dtype: object,
#  game_num                             1
#  event_id                          1002
#  event_time                    -29.8211
#  ball_pos_x                    -69.8298
#  ball_pos_y                      4.5178
#                                  ...
#  boost5_timer                       0.0
#  player_scoring_next                  3
#  team_scoring_next                    B
#  team_A_scoring_within_10sec          0
#  team_B_scoring_within_10sec          0
#  Name: 32, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -29.719934
#  ball_pos_x                       -66.679
#  ball_pos_y                        4.4914
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 33, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -29.610651
#  ball_pos_x                      -65.0154
#  ball_pos_y                        5.7346
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 34, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -29.50025
#  ball_pos_x                     -69.5308
#  ball_pos_y                      10.3464
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 35, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -29.385227
#  ball_pos_x                    -73.067406
#  ball_pos_y                       13.9586
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 36, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -29.278051
#  ball_pos_x                      -76.9142
#  ball_pos_y                       17.8876
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 37, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -29.16274
#  ball_pos_x                     -78.7356
#  ball_pos_y                        22.64
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 38, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -29.059345
#  ball_pos_x                       -76.159
#  ball_pos_y                     25.607399
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 39, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -28.947184
#  ball_pos_x                    -74.141205
#  ball_pos_y                     27.931398
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 40, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -28.839657
#  ball_pos_x                       -71.581
#  ball_pos_y                       30.8796
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 41, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -28.727491
#  ball_pos_x                      -69.2118
#  ball_pos_y                        33.608
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 42, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -28.619606
#  ball_pos_x                      -66.8506
#  ball_pos_y                     36.327198
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 43, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -28.510546
#  ball_pos_x                      -64.6782
#  ball_pos_y                       38.8292
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 44, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -28.400778
#  ball_pos_x                      -61.9718
#  ball_pos_y                        41.946
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 45, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                     -28.28668
#  ball_pos_x                    -59.814198
#  ball_pos_y                       44.4308
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 46, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -28.172428
#  ball_pos_x                    -57.484398
#  ball_pos_y                        47.114
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 47, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                     -28.06861
#  ball_pos_x                       -55.341
#  ball_pos_y                     49.582798
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 48, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -27.958885
#  ball_pos_x                      -52.7058
#  ball_pos_y                       52.6264
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 49, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -27.84513
#  ball_pos_x                      -50.995
#  ball_pos_y                      54.6988
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 50, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -27.738884
#  ball_pos_x                       -48.864
#  ball_pos_y                       57.2802
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 51, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                      -27.6244
#  ball_pos_x                    -48.772797
#  ball_pos_y                       55.0462
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 52, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -27.513058
#  ball_pos_x                    -49.994198
#  ball_pos_y                       49.6784
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 53, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -27.40885
#  ball_pos_x                     -51.1182
#  ball_pos_y                      44.7392
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 54, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -27.295181
#  ball_pos_x                      -52.3312
#  ball_pos_y                       39.4058
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 55, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -27.184788
#  ball_pos_x                    -53.447598
#  ball_pos_y                        34.498
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 56, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -27.077023
#  ball_pos_x                    -54.837997
#  ball_pos_y                       28.3848
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 57, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.960146
#  ball_pos_x                      -56.2226
#  ball_pos_y                       22.2948
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 58, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.839785
#  ball_pos_x                      -57.5104
#  ball_pos_y                       16.6318
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 59, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.733187
#  ball_pos_x                    -58.518997
#  ball_pos_y                       12.1962
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 60, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -26.62009
#  ball_pos_x                     -59.9808
#  ball_pos_y                       5.7674
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 61, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.499361
#  ball_pos_x                      -61.1644
#  ball_pos_y                        0.5628
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 62, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.385181
#  ball_pos_x                      -62.4344
#  ball_pos_y                        -5.023
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 63, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.278202
#  ball_pos_x                      -63.6098
#  ball_pos_y                      -10.1912
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 64, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.166183
#  ball_pos_x                      -64.6912
#  ball_pos_y                      -14.9468
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 65, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -26.051735
#  ball_pos_x                      -66.0382
#  ball_pos_y                       -20.871
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 66, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -25.938437
#  ball_pos_x                      -67.2908
#  ball_pos_y                        -26.38
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 67, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -25.829967
#  ball_pos_x                      -68.2714
#  ball_pos_y                      -30.6948
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 68, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -25.72024
#  ball_pos_x                     -69.5158
#  ball_pos_y                     -36.1688
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 69, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -25.60899
#  ball_pos_x                      -70.667
#  ball_pos_y                     -41.2342
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 70, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -25.49958
#  ball_pos_x                     -71.9906
#  ball_pos_y                      -47.058
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 71, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                     -25.39179
#  ball_pos_x                        -72.87
#  ball_pos_y                    -50.927998
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 72, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -25.277712
#  ball_pos_x                       -74.185
#  ball_pos_y                      -56.7142
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 73, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -25.165018
#  ball_pos_x                      -75.5818
#  ball_pos_y                      -62.8622
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 74, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -25.049944
#  ball_pos_x                    -76.712006
#  ball_pos_y                      -67.8392
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 75, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.945705
#  ball_pos_x                       -77.344
#  ball_pos_y                    -69.407005
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 76, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.834627
#  ball_pos_x                    -77.531204
#  ball_pos_y                      -67.3254
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 77, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.726032
#  ball_pos_x                       -77.704
#  ball_pos_y                        -65.41
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 78, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -24.60455
#  ball_pos_x                     -77.9192
#  ball_pos_y                     -63.0244
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   3
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 79, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.493418
#  ball_pos_x                      -78.1038
#  ball_pos_y                      -60.9644
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 80, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.387474
#  ball_pos_x                      -78.2742
#  ball_pos_y                       -59.069
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 81, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.279337
#  ball_pos_x                      -78.4444
#  ball_pos_y                      -57.1796
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 82, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.161623
#  ball_pos_x                      -78.6824
#  ball_pos_y                    -54.512596
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 83, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -24.049948
#  ball_pos_x                      -78.8504
#  ball_pos_y                       -52.637
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 84, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.937634
#  ball_pos_x                      -79.0592
#  ball_pos_y                    -50.300602
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 85, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.827658
#  ball_pos_x                      -79.2524
#  ball_pos_y                       -48.128
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 86, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.714931
#  ball_pos_x                       -79.418
#  ball_pos_y                      -46.2722
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 87, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.604784
#  ball_pos_x                       -79.625
#  ball_pos_y                      -43.9604
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 88, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.490602
#  ball_pos_x                      -79.7886
#  ball_pos_y                      -42.1174
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 89, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.385002
#  ball_pos_x                      -79.9654
#  ball_pos_y                      -40.1274
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 90, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.271523
#  ball_pos_x                      -80.0196
#  ball_pos_y                      -38.3168
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 91, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.162146
#  ball_pos_x                      -79.9048
#  ball_pos_y                       -36.245
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 92, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -23.055462
#  ball_pos_x                    -79.800804
#  ball_pos_y                      -34.3278
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 93, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -22.948483
#  ball_pos_x                      -79.6888
#  ball_pos_y                      -32.2704
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 94, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1002
#  event_time                    -22.838614
#  ball_pos_x                      -79.5848
#  ball_pos_y                    -30.366798
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    3
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 95, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1002
#  event_time                    -22.73571
#  ball_pos_x                     -79.4888
# ...
#  game_num                               1
#  event_id                            1003
#  event_time                    -61.197166
#  ball_pos_x                       65.9038
#  ball_pos_y                      -74.9112
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 968, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -61.085743
#  ball_pos_x                       63.9088
#  ball_pos_y                      -76.4234
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 969, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.975254
#  ball_pos_x                     62.062798
#  ball_pos_y                      -77.8226
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 970, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                     -60.86963
#  ball_pos_x                     60.647003
#  ball_pos_y                      -78.8956
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 971, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.763348
#  ball_pos_x                         58.53
#  ball_pos_y                      -80.5002
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 972, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                     -60.65801
#  ball_pos_x                     56.842403
#  ball_pos_y                      -81.7792
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 973, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.550087
#  ball_pos_x                     55.160202
#  ball_pos_y                      -83.0542
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 974, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.444702
#  ball_pos_x                       53.0648
#  ball_pos_y                       -84.642
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 975, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.330032
#  ball_pos_x                     51.394398
#  ball_pos_y                       -85.908
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 976, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.224785
#  ball_pos_x                       49.4522
#  ball_pos_y                     -87.37981
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 977, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.118053
#  ball_pos_x                     47.517002
#  ball_pos_y                      -88.8464
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 978, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -60.009098
#  ball_pos_x                       45.8638
#  ball_pos_y                      -90.0994
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 979, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -59.900475
#  ball_pos_x                       43.9412
#  ball_pos_y                      -91.5564
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 980, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -59.788734
#  ball_pos_x                     42.298798
#  ball_pos_y                    -92.800995
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 981, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -59.675953
#  ball_pos_x                       41.0188
#  ball_pos_y                    -88.550804
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 982, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -59.554688
#  ball_pos_x                       39.6722
#  ball_pos_y                      -83.9354
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 983, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1003
#  event_time                    -59.44259
#  ball_pos_x                        38.42
#  ball_pos_y                     -79.6436
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   4
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 984, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1003
#  event_time                    -59.32174
#  ball_pos_x                      37.3504
#  ball_pos_y                     -75.9772
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   4
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 985, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1003
#  event_time                    -59.20578
#  ball_pos_x                       36.018
#  ball_pos_y                       -71.41
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   4
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 986, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -59.090363
#  ball_pos_x                        34.956
#  ball_pos_y                       -67.769
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 987, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                     -58.98239
#  ball_pos_x                       33.5452
#  ball_pos_y                    -62.931602
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 988, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1003
#  event_time                    -58.87941
#  ball_pos_x                       32.947
#  ball_pos_y                     -60.8022
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   4
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 989, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -58.776905
#  ball_pos_x                     31.886799
#  ball_pos_y                    -57.029198
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 990, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -58.659504
#  ball_pos_x                       31.1606
#  ball_pos_y                    -54.443798
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 991, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                     -58.54675
#  ball_pos_x                     30.238998
#  ball_pos_y                    -51.163998
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 992, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -58.422894
#  ball_pos_x                     29.059399
#  ball_pos_y                      -46.9642
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 993, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -58.308693
#  ball_pos_x                     28.145401
#  ball_pos_y                      -43.7112
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 994, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1003
#  event_time                    -58.17516
#  ball_pos_x                      27.1696
#  ball_pos_y                     -40.2388
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   4
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 995, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -58.053493
#  ball_pos_x                       26.2624
#  ball_pos_y                      -37.0104
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 996, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -57.944836
#  ball_pos_x                       25.4874
#  ball_pos_y                       -34.252
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 997, Length: 61, dtype: object,
#  game_num                              1
#  event_id                           1003
#  event_time                    -57.83202
#  ball_pos_x                       24.458
#  ball_pos_y                     -30.5876
#                                   ...
#  boost5_timer                        0.0
#  player_scoring_next                   4
#  team_scoring_next                     B
#  team_A_scoring_within_10sec           0
#  team_B_scoring_within_10sec           0
#  Name: 998, Length: 61, dtype: object,
#  game_num                               1
#  event_id                            1003
#  event_time                    -57.707397
#  ball_pos_x                       22.8722
#  ball_pos_y                    -26.318998
#                                   ...
#  boost5_timer                         0.0
#  player_scoring_next                    4
#  team_scoring_next                      B
#  team_A_scoring_within_10sec            0
#  team_B_scoring_within_10sec            0
#  Name: 999, Length: 61, dtype: object,
#  ...]
